# %%
def suicide_tree(X3, X4, X6, X2=None, X5=None):

# ROOT NODE : X3 (Rescue Action)
# X3 = 2 (Not Available)

    if X3 == 2:

        return {
            "prediction": "Suicide",
            "probability": {
                "Failed Suicide": 0.02,
                "Suicide": 0.98
            },
            "node_percentage": "71%"
        }

# X3 = (Available)

    elif X3 == 1:

        # NODE X6
        # Risk4 Risk5 Risk6 Risk7
        if X6 in [4, 5, 6, 7]:

            return {
                "prediction": "Suicide",
                "probability": {
                    "Failed Suicide": 0.17,
                    "Suicide": 0.83
                },
                "node_percentage": "4%"
            }

        # Risk0 Risk1 Risk11 Risk12 Risk2 Risk3 Risk8
        elif X6 in [0, 1, 11, 12, 2, 3, 8]:
            # NODE X4
            # Method2 Method3 Method5 Method7 Method8
            if X4 in [2, 3, 5, 7, 8]:

                return {
                    "prediction": "Failed Suicide",
                    "probability": {
                        "Failed Suicide": 0.87,
                        "Suicide": 0.13
                    },
                    "node_percentage": "15%"
                }

            # Method1 Method4 Method6
            elif X4 in [1, 4, 6]:

                # NODE X6 LAGI
                # Risk1 Risk11 Risk2
                if X6 in [1, 11, 2]:

                    return {
                        "prediction": "Failed Suicide",
                        "probability": {
                            "Failed Suicide": 0.86,
                            "Suicide": 0.14
                        },
                        "node_percentage": "2%"
                    }

                # Risk0 Risk8
                elif X6 in [0, 8]:

                    # x2 dulu baru x5
                    if X2 is not None:

                        # Mature, Adolescent, Unknown
                        if X2 in [4, 2, 0]:

                            return {
                                "prediction": "Failed Suicide",
                                "probability": {
                                    "Failed Suicide": 0.54,
                                    "Suicide": 0.46
                                },
                                "node_percentage": "4%"
                            }

                        # Elderly, Children, Young Adult
                        elif X2 in [5, 1, 3]:

                            return {
                                "prediction": "Suicide",
                                "probability": {
                                    "Failed Suicide": 0.30,
                                    "Suicide": 0.70
                                },
                                "node_percentage": "3%"
                            }

                    elif X5 is not None:

                        # Disorder0 = Unknown Mental Disorder
                        if X5 == 0:

                            return {
                                "prediction": "Failed Suicide",
                                "probability": {
                                    "Failed Suicide": 0.54,
                                    "Suicide": 0.46
                                },
                                "node_percentage": "4%"
                            }

                        # Disorder1 = Depression
                        elif X5 == 1:

                            return {
                                "prediction": "Suicide",
                                "probability": {
                                    "Failed Suicide": 0.30,
                                    "Suicide": 0.70
                                },
                                "node_percentage": "3%"
                            }

                        # Disorder selain 0 dan 1
                        else:

                            return {
                                "nilai tidak sesuai"
                            }

                    #jika x2 x5 kosong
                    else:

                        return {
                            "isi salah satu x5/x2"
                        }
    return {
        "Kombinasi tidak sesuai tree"
    }

"""BAGIAN INPUT TERMINAL"""
print("Masukkan Data Prediksi")

try:
    input_X3 = int(input("Masukkan nilai X3: "))
    input_X4 = int(input("Masukkan nilai X4: "))
    input_X6 = int(input("Masukkan nilai X6: "))

    raw_X2 = input("Masukkan nilai X2 (Jika tidak ada nilai X2 kosongkan kolom dengan tekan Enter): ")
    input_X2 = int(raw_X2) if raw_X2.strip() != "" else None
    raw_X5 = input("Masukkan nilai X5 (Jika tidak ada nilai X5 kosongkan kolom dengan tekan Enter): ")
    input_X5 = int(raw_X5) if raw_X5.strip() != "" else None

    hasil = suicide_tree(
        X3=input_X3,
        X4=input_X4,
        X6=input_X6,
        X2=input_X2,
        X5=input_X5
    )

    print("\nHasil Prediksi")
    print(hasil)

except ValueError:
    print("\n[Error] Harap masukkan kriteria yang sesuai dalam daftar!")
# Out:
# Masukkan Data Prediksi
# Masukkan nilai X3: 2
# Masukkan nilai X4: 1
# Masukkan nilai X6: 0
# Masukkan nilai X2 (Jika tidak ada nilai X2 kosongkan kolom dengan tekan Enter): 8
# Masukkan nilai X5 (Jika tidak ada nilai X5 kosongkan kolom dengan tekan Enter): 8
#
# Hasil Prediksi
# {'prediction': 'Suicide', 'probability': {'Failed Suicide': 0.02, 'Suicide': 0.98}, 'node_percentage': '71%'}

# %%
# Definisi Node (Simpul)
class Node:
    def __init__(self, data):
        self.data = data                # Nilai data
        self.left = None                # Anak kiri
        self.right = None               # Anak kanan

# Membuat Node secara manual
root = Node("Try Sucide")
node1 = Node("X3 : Available")
node2 = Node("X3 : No Available")
node3 = Node("X6 : 0, 1, 11, 12, 2, 3, 8")
node4 = Node("X6 : 4, 5, 6, 7")
node5 = Node("X4 : 2, 3, 5, 7, 8")
node6 = Node("X4 : 1, 4, 6")
node7 = Node("X6 : 1, 11, 2")
node8 = Node("X6 : 0, 8")
node9 = Node("X5 : 0 / X2 : Adult, Teens, Unknown")
node10 = Node("X5 : 1 / X2 : Elderly, Kids, Young, Adult")

# Menghubungkan node
root.left = node1
root.right = node2
node1.left = node3
node1.right = node4
node3.left = node5
node3.right = node6
node6.left = node7
node6.right = node8
node8.left = node9
node8.right = node10

# Fungsi untuk menampilkan Tree (Traversal Sederhana)
def cetak_tree(node, prefix="", is_left=True):
    if node is not None:
        # Menentukan simbol garis untuk node saat ini
        if prefix == "":
            print(str(node.data)) # Node Root tidak memakai garis pembuka
        else:
            connector = "├── " if is_left else "└── "
            print(prefix + connector + str(node.data))

        # Menambahkan garis vertikal untuk anak-anak node berikutnya
        new_prefix = prefix + ("│   " if is_left else "    ")

        # Rekursi untuk anak kiri dan kanan
        if node.left or node.right:
            cetak_tree(node.left, new_prefix, is_left=True)
            cetak_tree(node.right, new_prefix, is_left=False)

# Menjalankan fungsi
print("Struktur Tree:")
cetak_tree(root)
# Out:
# Struktur Tree:
# Try Sucide
# │   ├── X3 : Available
# │   │   ├── X6 : 0, 1, 11, 12, 2, 3, 8
# │   │   │   ├── X4 : 2, 3, 5, 7, 8
# │   │   │   └── X4 : 1, 4, 6
# │   │   │       ├── X6 : 1, 11, 2
# │   │   │       └── X6 : 0, 8
# │   │   │           ├── X5 : 0 / X2 : Adult, Teens, Unknown
# │   │   │           └── X5 : 1 / X2 : Elderly, Kids, Young, Adult
# │   │   └── X6 : 4, 5, 6, 7
# │   └── X3 : No Available
